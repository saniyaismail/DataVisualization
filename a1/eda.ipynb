# %%
import pandas as pd
# Out:
# /home/dyuthi/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/dyuthi/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv('spotify_songs.csv')

# %%
df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
df.isna().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
df[df.track_name.isna()]
# Out:
#                      track_id track_name track_artist  track_popularity  \
# 8151   69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
# 9282   5cjecvX0CmC9gK0Laf5EMQ        NaN          NaN                 0
# 9283   5TTzhRSWQS4Yu8xTgAuq6D        NaN          NaN                 0
# 19568  3VKFip3OdAvv4OfNTgFWeQ        NaN          NaN                 0
# 19811  69gRFGOWY9OMpFJgFol1u0        NaN          NaN                 0
#
#                track_album_id track_album_name track_album_release_date  \
# 8151   717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 9282   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 9283   3luHJEPw434tvNbme3SP8M              NaN               2017-12-01
# 19568  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
# 19811  717UG2du6utFe7CdmpuUe3              NaN               2012-01-05
#
#             playlist_name             playlist_id playlist_genre  ... key  \
# ...

# %%
df.shape
# Out:
# (32833, 23)

# %%
df.dropna(inplace=True)

# %%
df.to_csv('spotify_songs_without_null.csv')

# %%
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
df.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32828.000000  32828.000000  32828.000000  32828.000000
# mean          42.483551      0.654850      0.698603      5.373949
# std           24.980476      0.145092      0.180916      3.611572
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32828.000000  32828.000000  32828.000000  32828.000000
# mean      -6.719529      0.565737      0.107053      0.175352
# std        2.988641      0.495667      0.101307      0.219644
# min      -46.448000      0.000000      0.000000      0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df['track_name'].duplicated()]
# Out:
#                      track_id                                  track_name  \
# 154    09CtPGIpYB4BrO8qb1RGsF                                       Sorry
# 193    3BOcWxFUURAomDXRSDFve4                              Something Real
# 209    4TIkSdsNSfqpuq6ZYvCjAz  All You Need To Know (feat. Calle Lehmann)
# 232    3sHuIjfAzluc6S9cXoqfqC                                Let It Be Me
# 272    36orMWv2PgvnzXsd5CJ0yL                    Post Malone (feat. RANI)
# ...                       ...                                         ...
# 32802  3Gwq0zKnMWluOEPKh93BeC                                 Lost At Sea
# 32804  2KlZexJjJPuNWcN5uAG1GU                           Gold (feat. Yuna)
# 32808  5QcSDOm6mcvFDl7KBT1fHv      Spaceman - Carnage Festival Trap Remix
# 32824  3zKST4nk4QJE77oLjUZ0Ng                                 Hey Brother
# 32826  1EavLSmwRWtmkKEmlCfFzT                                      Wasted
#
#            track_artist  track_popularity          track_album_id  \
# ...

# %%
df[df['track_name'] == 'Sorry']
# Out:
#                      track_id track_name   track_artist  track_popularity  \
# 127    6y1UtRcHQU07aUs3oxZ8Yn      Sorry     Joel Corry                75
# 154    09CtPGIpYB4BrO8qb1RGsF      Sorry  Justin Bieber                81
# 1719   09CtPGIpYB4BrO8qb1RGsF      Sorry  Justin Bieber                81
# 3777   09CtPGIpYB4BrO8qb1RGsF      Sorry  Justin Bieber                81
# 5397   3UNuVVGosJLfLCsWHEhr5U      Sorry         Aquilo                 5
# 8133   69bp2EbF7Q2rqc5N3ylezZ      Sorry  Justin Bieber                21
# 11284  4g9TfQAiEN6lDNRJJsiU9T      Sorry  Guns N' Roses                49
# 17217  1J9vFKjtJCR5WqTswBalnb      Sorry           WUSA                33
# 22193  2xRyZfWe9bnRfH1ZfhYO98      Sorry          6LACK                60
# 28259  3IVNVCvG7ZBo30FsSy75Pf      Sorry  Chester Young                 0
# 30464  09CtPGIpYB4BrO8qb1RGsF      Sorry  Justin Bieber                81
#
#                track_album_id          track_album_name  \
# ...

# %%
df.track_artist.nunique()
# Out:
# 10692

# %%
# to check artist popularity, dropping songs repeated over different playlists
duplicate_records = df[df.duplicated(subset=['track_name', 'track_album_id'], keep=False)]

# %%
duplicate_records
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 5      7fvUMiyapMsRRxr07cU8Ef
# 7      6b1RNvAcJjQH73eZO4BLAB
# ...                       ...
# 32783  1mzGywacjpeik00PVLBPpF
# 32793  1nas007nDbzLwDGwvMdz79
# 32798  65hRZOQkVjmBdusz1N7aOv
# 32804  2KlZexJjJPuNWcN5uAG1GU
# 32808  5QcSDOm6mcvFDl7KBT1fHv
#
#                                               track_name         track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...           Ed Sheeran
# 1                        Memories - Dillon Francis Remix             Maroon 5
# 2                        All the Time - Don Diablo Remix         Zara Larsson
# 5      Beautiful People (feat. Khalid) - Jack Wins Remix           Ed Sheeran
# 7               Post Malone (feat. RANI) - GATTÜSO Remix            Sam Feldt
# ...                                                  ...                  ...
# ...

# %%
duplicate_records[duplicate_records['track_album_id'] == '2oCs0DGTsRO98Gh5ZSl2Cx']
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 29684  6f807x0ima9a1j3VPbc7VN
#
#                                               track_name track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...   Ed Sheeran
# 29684  I Don't Care (with Justin Bieber) - Loud Luxur...   Ed Sheeran
#
#        track_popularity          track_album_id  \
# 0                    66  2oCs0DGTsRO98Gh5ZSl2Cx
# 29684                66  2oCs0DGTsRO98Gh5ZSl2Cx
#
#                                         track_album_name  \
# 0      I Don't Care (with Justin Bieber) [Loud Luxury...
# 29684  I Don't Care (with Justin Bieber) [Loud Luxury...
#
#       track_album_release_date    playlist_name             playlist_id  \
# 0                   2019-06-14        Pop Remix  37i9dQZF1DXcZDD7cfEKhW
# 29684               2019-06-14  Pop EDM Remixes  4aUEH3uhbofktrFkXOOaKj
#
#       playlist_genre  ... key  loudness  mode  speechiness  acousticness  \
# ...

# %%
df_no_duplicates = df.drop_duplicates(subset=['track_name', 'track_album_id'], keep=False)

# %%
df_no_duplicates.shape
# Out:
# (25177, 23)

# %%
df_no_duplicates.to_csv('spotify_songs_without_duplicates.csv')

# %%
artist_popularity = df_no_duplicates.groupby('track_artist')['track_popularity'].mean().reset_index()
artist_popularity = artist_popularity.sort_values(by='track_popularity', ascending=False)

# %%
artist_popularity.head(30)
# Out:
#          track_artist  track_popularity
# 377         Ali Gatie              89.0
# 557      Ant Saunders              89.0
# 2133     Dadá Boladão              84.0
# 6822   Olivia Rodrigo              83.0
# 2498      Don Toliver              83.0
# 7585   Rich Music LTD              82.5
# 4046         JACKBOYS              82.0
# 8119        Sheck Wes              82.0
# 6528              Nea              81.0
# 7691      Roddy Ricch              80.5
# 4656      Kaash Paige              80.0
# 5490         Ludmilla              80.0
# 3094     Flipp Dinero              80.0
# 7364              RIN              80.0
# 580        Apache 207              80.0
# 9881        YNW Melly              79.5
# 331     Alex & Sierra              79.0
# 6950           PUBLIC              79.0
# 2344     Dennis Lloyd              79.0
# 4644              KSI              79.0
# 1458           Camilo              78.0
# 2467         Dj Guuga              78.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select top 10 artists for visualization (optional)
top_artists = artist_popularity.head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='track_artist', y='track_popularity', data=top_artists, palette='viridis')
plt.xlabel('Artist')
plt.ylabel('Average Track Popularity')
plt.title('Top 10 Artists by Average Track Popularity')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df[df['track_artist'] == 'Ant Saunders']
# Out:
#                      track_id     track_name  track_artist  track_popularity  \
# 1224   2W4yABdLc4Jnds67Poi5Nl  Yellow Hearts  Ant Saunders                89
# 2021   20JtELGPfOAMq7FpUt8eSM  Yellow Hearts  Ant Saunders                62
# 18331  20JtELGPfOAMq7FpUt8eSM  Yellow Hearts  Ant Saunders                62
# 19741  20JtELGPfOAMq7FpUt8eSM  Yellow Hearts  Ant Saunders                62
# 23646  20JtELGPfOAMq7FpUt8eSM  Yellow Hearts  Ant Saunders                62
#
#                track_album_id track_album_name track_album_release_date  \
# 1224   7L5mva8yC5ctamvs4XzgpR    Yellow Hearts               2019-06-18
# 2021   0ahjnylJzSIfobrUbMZnmL    Yellow Hearts               2019-06-18
# 18331  0ahjnylJzSIfobrUbMZnmL    Yellow Hearts               2019-06-18
# 19741  0ahjnylJzSIfobrUbMZnmL    Yellow Hearts               2019-06-18
# 23646  0ahjnylJzSIfobrUbMZnmL    Yellow Hearts               2019-06-18
#
#                                            playlist_name  \
# ...

# %%
artist_popularity[artist_popularity['track_artist'] == 'Ant Saunders']
# Out:
#      track_artist  track_popularity
# 557  Ant Saunders              89.0
